# %%
# Start writing code here...
import time
import json

def read_json_file(path):
    print("Processing: " + path)
    t1 = time.time()
    with open(path) as f:
        data = json.load(f)
    t = time.time() - t1
    print(t)
    print() 
    return data

link = '/work/nlab_plain.json'

read_file = read_json_file(link)
# Out:
# Processing: /work/nlab_plain.json
# 0.6868908405303955

# %%
import requests
import time
import ast

t = time.time()

files = {
        'data': (None, read_file[1]['content']),
        'model': (None, 'english'),
        'tokenizer': (None, ''),
        'tagger': (None, ''),
        'parser': (None, ''),
    }

response = requests.post('http://lindat.mff.cuni.cz/services/udpipe/api/process', files=files)
byte_str = response.content
dict_str = byte_str.decode("UTF-8")
mydata = ast.literal_eval(dict_str)
out = mydata['result']
    #i['UD Results'] = out
timer = time.time() - t
print(timer)
# Out:
# 0.8487136363983154

# %%
print(out)
# Out:
# # generator = UDPipe 2, https://lindat.mff.cuni.cz/services/udpipe
# # udpipe_model = english-ewt-ud-2.6-200830
# # udpipe_model_licence = CC BY-NC-SA
# # newdoc
# # newpar
# # sent_id = 1
# # text = ##Informal definition##
# 1	##Informal	##informal	ADJ	JJ	Degree=Pos	2	amod	_	_
# 2	definition	definition	NOUN	NN	Number=Sing	0	root	_	SpaceAfter=No
# 3	##	##	SYM	NFP	_	2	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 2
# # text = Toda-Smith complexes are finite spectra characterized by having a particularly simple homology, and are used in stable homotopy theory.
# 1	Toda	Toda	PROPN	NNP	Number=Sing	3	compound	_	SpaceAfter=No
# 2	-Smith	-smith	PROPN	NNP	Number=Sing	1	flat	_	_
# 3	complexes	complex	NOUN	NNS	Number=Plur	6	nsubj	_	_
# 4	are	be	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	6	cop	_	_
# 5	finite	finite	ADJ	JJ	Degree=Pos	6	amod	_	_
# 6	spectra	spectra	NOUN	NN	Number=Sing	0	root	_	_
# 7	characterized	characterize	VERB	VBN	Tense=Past|VerbForm=Part	6	acl	_	_
# 8	by	by	SCONJ	IN	_	9	mark	_	_
# 9	having	have	VERB	VBG	VerbForm=Ger	7	advcl	_	_
# 10	a	a	DET	DT	Definite=Ind|PronType=Art	13	det	_	SpacesAfter=\n
# 11	particularly	particularly	ADV	RB	_	12	advmod	_	_
# 12	simple	simple	ADJ	JJ	Degree=Pos	13	amod	_	_
# 13	homology	homology	NOUN	NN	Number=Sing	9	obj	_	SpaceAfter=No
# 14	,	,	PUNCT	,	_	17	punct	_	_
# 15	and	and	CCONJ	CC	_	17	cc	_	_
# 16	are	be	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	17	aux:pass	_	_
# 17	used	use	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	6	conj	_	_
# 18	in	in	ADP	IN	_	21	case	_	_
# 19	stable	stable	ADJ	JJ	Degree=Pos	21	amod	_	_
# 20	homotopy	homotopy	NOUN	NN	Number=Sing	21	compound	_	_
# 21	theory	theory	NOUN	NN	Number=Sing	17	obl	_	SpaceAfter=No
# 22	.	.	PUNCT	.	_	6	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 3
# # text = Toda-Smith complexes provided examples of periodic maps.
# 1	Toda	Toda	PROPN	NNP	Number=Sing	4	compound	_	SpaceAfter=No
# 2	-	-	PUNCT	HYPH	_	1	punct	_	SpaceAfter=No
# 3	Smith	Smith	PROPN	NNP	Number=Sing	1	flat	_	_
# 4	complexes	complex	NOUN	NNS	Number=Plur	5	nsubj	_	_
# 5	provided	provide	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root	_	_
# 6	examples	example	NOUN	NNS	Number=Plur	5	obj	_	_
# 7	of	of	ADP	IN	_	9	case	_	_
# 8	periodic	periodic	ADJ	JJ	Degree=Pos	9	amod	_	_
# 9	maps	map	NOUN	NNS	Number=Plur	6	nmod	_	SpaceAfter=No
# 10	.	.	PUNCT	.	_	5	punct	_	_
#
# # sent_id = 4
# # text = Thus, they led to the construction of the nilpotent and periodicity theorems, which provided the first organization of the stable homotopy groups of spheres (localized at a prime) into families of maps via chromatic homotopy theory.
# 1	Thus	thus	ADV	RB	_	4	advmod	_	SpaceAfter=No
# 2	,	,	PUNCT	,	_	4	punct	_	_
# 3	they	they	PRON	PRP	Case=Nom|Number=Plur|Person=3|PronType=Prs	4	nsubj	_	_
# 4	led	lead	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root	_	SpacesAfter=\n
# 5	to	to	ADP	IN	_	7	case	_	_
# 6	the	the	DET	DT	Definite=Def|PronType=Art	7	det	_	_
# 7	construction	construction	NOUN	NN	Number=Sing	4	obl	_	_
# 8	of	of	ADP	IN	_	13	case	_	_
# 9	the	the	DET	DT	Definite=Def|PronType=Art	13	det	_	_
# 10	nilpotent	nilpotent	ADJ	JJ	Degree=Pos	13	amod	_	_
# 11	and	and	CCONJ	CC	_	12	cc	_	_
# 12	periodicity	periodicity	NOUN	NN	Number=Sing	10	conj	_	_
# 13	theorems	theorem	NOUN	NNS	Number=Plur	7	nmod	_	SpaceAfter=No
# 14	,	,	PUNCT	,	_	7	punct	_	_
# 15	which	which	PRON	WDT	PronType=Rel	16	nsubj	_	SpacesAfter=\n
# 16	provided	provide	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	13	acl:relcl	_	_
# 17	the	the	DET	DT	Definite=Def|PronType=Art	19	det	_	_
# 18	first	first	ADJ	JJ	Degree=Pos|NumType=Ord	19	amod	_	_
# 19	organization	organization	NOUN	NN	Number=Sing	16	obj	_	_
# 20	of	of	ADP	IN	_	24	case	_	_
# 21	the	the	DET	DT	Definite=Def|PronType=Art	24	det	_	_
# 22	stable	stable	ADJ	JJ	Degree=Pos	24	amod	_	_
# 23	homotopy	homotopy	NOUN	NN	Number=Sing	24	compound	_	_
# 24	groups	group	NOUN	NNS	Number=Plur	19	nmod	_	_
# 25	of	of	ADP	IN	_	26	case	_	_
# 26	spheres	sphere	NOUN	NNS	Number=Plur	24	nmod	_	SpacesAfter=\n
# 27	(	(	PUNCT	-LRB-	_	28	punct	_	SpaceAfter=No
# 28	localized	localize	VERB	VBN	Tense=Past|VerbForm=Part	24	acl	_	_
# 29	at	at	ADP	IN	_	31	case	_	_
# 30	a	a	DET	DT	Definite=Ind|PronType=Art	31	det	_	_
# 31	prime	prime	NOUN	NN	Number=Sing	28	obl	_	SpaceAfter=No
# 32	)	)	PUNCT	-RRB-	_	28	punct	_	_
# 33	into	into	ADP	IN	_	34	case	_	_
# 34	families	family	NOUN	NNS	Number=Plur	16	obl	_	_
# 35	of	of	ADP	IN	_	36	case	_	_
# 36	maps	map	NOUN	NNS	Number=Plur	34	nmod	_	_
# 37	via	via	ADP	IN	_	40	case	_	_
# 38	chromatic	chromatic	ADJ	JJ	Degree=Pos	40	amod	_	_
# 39	homotopy	homotopy	NOUN	NN	Number=Sing	40	compound	_	SpacesAfter=\n
# 40	theory	theory	NOUN	NN	Number=Sing	34	nmod	_	SpaceAfter=No
# 41	.	.	PUNCT	.	_	4	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 5
# # text = Mathematical Context
# 1	Mathematical	mathematical	ADJ	JJ	Degree=Pos	2	amod	_	_
# 2	Context	context	NOUN	NN	Number=Sing	0	root	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 6
# # text = The story begins with the degree p map on S¹ (as a circle in the complex plane):
# 1	The	the	DET	DT	Definite=Def|PronType=Art	2	det	_	_
# 2	story	story	NOUN	NN	Number=Sing	3	nsubj	_	_
# 3	begins	begin	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
# 4	with	with	ADP	IN	_	8	case	_	_
# 5	the	the	DET	DT	Definite=Def|PronType=Art	8	det	_	_
# 6	degree	degree	NOUN	NN	Number=Sing	7	compound	_	_
# 7	p	p	NOUN	NN	Number=Sing	8	compound	_	_
# 8	map	map	NOUN	NN	Number=Sing	3	obl	_	_
# 9	on	on	ADP	IN	_	10	case	_	_
# 10	S¹	s¹	NOUN	NN	Number=Sing	8	nmod	_	_
# 11	(	(	PUNCT	-LRB-	_	14	punct	_	SpaceAfter=No
# 12	as	as	ADP	IN	_	14	case	_	_
# 13	a	a	DET	DT	Definite=Ind|PronType=Art	14	det	_	_
# 14	circle	circle	NOUN	NN	Number=Sing	8	nmod	_	_
# 15	in	in	ADP	IN	_	18	case	_	_
# 16	the	the	DET	DT	Definite=Def|PronType=Art	18	det	_	_
# 17	complex	complex	ADJ	JJ	Degree=Pos	18	amod	_	SpacesAfter=\n
# 18	plane	plane	NOUN	NN	Number=Sing	14	nmod	_	SpaceAfter=No
# 19	)	)	PUNCT	-RRB-	_	14	punct	_	SpaceAfter=No
# 20	:	:	PUNCT	:	_	3	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 7
# # text = S¹ → S¹ z ↦ z^(p)
# 1	S¹	s¹	X	NNP	_	0	root	_	SpacesAfter=
# 2	→	→	X	SYM	_	1	goeswith	_	SpacesAfter=
# 3	S¹	s¹	X	NN	_	1	nmod	_	SpacesAfter=\n
# 4	z	z	NOUN	NN	Number=Sing	1	goeswith	_	SpacesAfter=
# 5	↦	↦	SYM	NN	_	1	goeswith	_	SpacesAfter=
# 6	z^	z^	NOUN	NN	Number=Sing	1	appos	_	SpaceAfter=No
# 7	(	(	PUNCT	-LRB-	_	8	punct	_	SpaceAfter=No
# 8	p	p	NOUN	NN	Number=Sing	6	appos	_	SpaceAfter=No
# 9	)	)	PUNCT	-RRB-	_	8	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 8
# # text = The degree p map is well defined for S^(k) in general, where k ∈ mathN.
# 1	The	the	DET	DT	Definite=Def|PronType=Art	4	det	_	_
# 2	degree	degree	NOUN	NN	Number=Sing	3	compound	_	_
# 3	p	p	NOUN	NN	Number=Sing	4	compound	_	_
# 4	map	map	NOUN	NN	Number=Sing	7	nsubj:pass	_	_
# 5	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	7	aux:pass	_	_
# 6	well	well	ADV	RB	Degree=Pos	7	advmod	_	_
# 7	defined	define	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	0	root	_	_
# 8	for	for	ADP	IN	_	9	case	_	_
# 9	S^	s^	NOUN	NN	Number=Sing	7	obl	_	SpaceAfter=No
# 10	(	(	PUNCT	-LRB-	_	11	punct	_	SpaceAfter=No
# 11	k	k	NOUN	NN	Number=Sing	9	appos	_	SpaceAfter=No
# 12	)	)	PUNCT	-RRB-	_	11	punct	_	_
# 13	in	in	ADP	IN	_	14	case	_	_
# 14	general	general	ADJ	JJ	Degree=Pos	7	obl	_	SpaceAfter=No
# 15	,	,	PUNCT	,	_	9	punct	_	_
# 16	where	where	ADV	WRB	PronType=Rel	18	advmod	_	_
# 17	k	k	NOUN	NN	Number=Sing	18	nsubj	_	SpacesAfter=
# 18	∈	∈	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	9	acl:relcl	_	SpacesAfter=
# 19	mathN	mathn	NOUN	NN	Number=Sing	18	obj	_	SpaceAfter=No
# 20	.	.	PUNCT	.	_	7	punct	_	SpacesAfter=\n
#
# # sent_id = 9
# # text = If we apply the infinite suspension functor to this map, Σ^(∞)S¹ → Σ^(∞)S¹ = : 𝕊¹ → 𝕊¹ and we take the cofiber of the resulting map:
# 1	If	if	SCONJ	IN	_	3	mark	_	_
# 2	we	we	PRON	PRP	Case=Nom|Number=Plur|Person=1|PronType=Prs	3	nsubj	_	_
# 3	apply	apply	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	21	advcl	_	_
# 4	the	the	DET	DT	Definite=Def|PronType=Art	7	det	_	_
# 5	infinite	infinite	ADJ	JJ	Degree=Pos	7	amod	_	_
# 6	suspension	suspension	NOUN	NN	Number=Sing	7	compound	_	_
# 7	functor	functor	NOUN	NN	Number=Sing	3	obj	_	_
# 8	to	to	ADP	IN	_	10	case	_	_
# 9	this	this	DET	DT	Number=Sing|PronType=Dem	10	det	_	_
# 10	map	map	NOUN	NN	Number=Sing	3	obl	_	SpaceAfter=No
# 11	,	,	PUNCT	,	_	21	punct	_	SpacesAfter=\n
# 12	Σ^	σ^	NOUN	NN	Number=Sing	15	compound	_	SpaceAfter=No
# 13	(	(	PUNCT	-LRB-	_	15	punct	_	SpaceAfter=No
# 14	∞)	∞)	SYM	CD	_	15	nummod	_	SpaceAfter=No
# 15	S¹	s¹	NOUN	NN	Number=Sing	21	nsubj	_	SpacesAfter=
# 16	→	→	SYM	SYM	_	21	case	_	SpacesAfter=
# 17	Σ^	σ^	NOUN	NN	Number=Sing	20	compound	_	SpaceAfter=No
# 18	(	(	PUNCT	-LRB-	_	20	punct	_	SpaceAfter=No
# 19	∞)	∞)	SYM	LS	_	20	compound	_	SpaceAfter=No
# 20	S¹	s¹	NOUN	NN	Number=Sing	21	obl	_	SpacesAfter=
# 21	=	=	SYM	SYM	_	0	root	_	SpacesAfter=
# 22	:	:	PUNCT	:	_	21	punct	_	SpacesAfter=
# 23	𝕊¹	𝕊¹	SYM	NN	Number=Sing	21	appos	_	SpacesAfter=
# 24	→	→	SYM	SYM	_	25	case	_	SpacesAfter=
# 25	𝕊¹	𝕊¹	NOUN	NN	Number=Sing	23	nmod	_	_
# 26	and	and	CCONJ	CC	_	28	cc	_	_
# 27	we	we	PRON	PRP	Case=Nom|Number=Plur|Person=1|PronType=Prs	28	nsubj	_	_
# 28	take	take	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	21	conj	_	_
# 29	the	the	DET	DT	Definite=Def|PronType=Art	30	det	_	_
# 30	cofiber	cofiber	NOUN	NN	Number=Sing	28	obj	_	_
# 31	of	of	ADP	IN	_	34	case	_	_
# 32	the	the	DET	DT	Definite=Def|PronType=Art	34	det	_	_
# 33	resulting	result	VERB	VBG	VerbForm=Ger	34	amod	_	SpacesAfter=\n
# 34	map	map	NOUN	NN	Number=Sing	30	nmod	_	SpaceAfter=No
# 35	:	:	PUNCT	:	_	21	punct	_	SpacesAfter=\n\n\n\n
#
# # newpar
# # sent_id = 10
# # text = We find that S/p has the remarkable property of coming from a Moore space (i.e., a designer (co)homology space:
# 1	We	we	PRON	PRP	Case=Nom|Number=Plur|Person=1|PronType=Prs	2	nsubj	_	_
# 2	find	find	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	0	root	_	_
# 3	that	that	SCONJ	IN	_	7	mark	_	_
# 4	S	s	NOUN	NN	Number=Sing	6	compound	_	SpaceAfter=No
# 5	/	/	PUNCT	,	_	6	punct	_	SpaceAfter=No
# 6	p	p	NOUN	NN	Number=Sing	7	nsubj	_	_
# 7	has	have	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	2	ccomp	_	_
# 8	the	the	DET	DT	Definite=Def|PronType=Art	10	det	_	_
# 9	remarkable	remarkable	ADJ	JJ	Degree=Pos	10	amod	_	_
# 10	property	property	NOUN	NN	Number=Sing	7	obj	_	_
# 11	of	of	SCONJ	IN	_	12	mark	_	_
# 12	coming	come	VERB	VBG	VerbForm=Ger	10	acl	_	_
# 13	from	from	ADP	IN	_	16	case	_	_
# 14	a	a	DET	DT	Definite=Ind|PronType=Art	16	det	_	_
# 15	Moore	Moore	PROPN	NNP	Number=Sing	16	compound	_	SpacesAfter=\n
# 16	space	space	NOUN	NN	Number=Sing	12	obl	_	_
# 17	(	(	PUNCT	-LRB-	_	26	punct	_	SpaceAfter=No
# 18	i.e.	i.e.	X	FW	_	26	advmod	_	SpaceAfter=No
# 19	,	,	PUNCT	,	_	26	punct	_	_
# 20	a	a	DET	DT	Definite=Ind|PronType=Art	26	det	_	_
# 21	designer	designer	NOUN	NN	Number=Sing	26	compound	_	_
# 22	(	(	PUNCT	-LRB-	_	23	punct	_	SpaceAfter=No
# 23	co	co	X	AFX	_	25	compound	_	SpaceAfter=No
# 24	)	)	PUNCT	-RRB-	_	23	punct	_	SpaceAfter=No
# 25	homology	homology	NOUN	NN	Number=Sing	26	compound	_	_
# 26	space	space	NOUN	NN	Number=Sing	16	appos	_	SpaceAfter=No
# 27	:	:	PUNCT	:	_	2	punct	_	_
#
# # sent_id = 11
# # text = H^(n)(X) ≃ Z/p, and H̃^(*)(X) is trivial for all * ≠ n).
# 1	H^	h^	INTJ	UH	_	0	root	_	SpaceAfter=No
# 2	(	(	PUNCT	-LRB-	_	3	punct	_	SpaceAfter=No
# 3	n	n	X	NN	Number=Sing	1	appos	_	SpaceAfter=No
# 4	)	)	PUNCT	-RRB-	_	6	punct	_	SpaceAfter=No
# 5	(	(	PUNCT	-LRB-	_	6	punct	_	SpaceAfter=No
# 6	X	x	NOUN	NN	Number=Sing	1	appos	_	SpaceAfter=No
# 7	)	)	PUNCT	-RRB-	_	6	punct	_	SpacesAfter=
# 8	≃	≃	SYM	SYM	_	9	case	_	SpacesAfter=
# 9	Z/p	z/p	NOUN	NN	Number=Sing	1	nmod	_	SpaceAfter=No
# 10	,	,	PUNCT	,	_	19	punct	_	_
# 11	and	and	CCONJ	CC	_	19	cc	_	_
# 12	H̃^	h̃^	NOUN	NN	_	19	nsubj	_	SpaceAfter=No
# 13	(	(	PUNCT	-LRB-	_	16	punct	_	SpaceAfter=No
# 14	*)	*)	SYM	NFP	_	12	appos	_	SpaceAfter=No
# 15	(	(	PUNCT	-LRB-	_	16	punct	_	SpaceAfter=No
# 16	X	x	NOUN	NN	Number=Sing	12	appos	_	SpaceAfter=No
# 17	)	)	PUNCT	-RRB-	_	16	punct	_	SpacesAfter=\n
# 18	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	19	cop	_	_
# 19	trivial	trivial	ADJ	JJ	Degree=Pos	9	conj	_	_
# 20	for	for	ADP	IN	_	23	case	_	_
# 21	all	all	DET	DT	_	23	det	_	SpacesAfter=\s
# 22	*	*	SYM	NFP	_	23	punct	_	SpacesAfter=
# 23	≠	≠	SYM	SYM	_	19	obl	_	SpacesAfter=
# 24	n	n	NUM	CD	NumType=Card	23	nummod	_	SpaceAfter=No
# 25	)	)	PUNCT	-RRB-	_	19	punct	_	SpaceAfter=No
# 26	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 12
# # text = Formal definition
# 1	Formal	formal	ADJ	JJ	Degree=Pos	2	amod	_	_
# 2	definition	definition	NOUN	NN	Number=Sing	0	root	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 13
# # text = The nth Toda-Smith complex, V(n) where n ∈ { − 1, 0, 1, 2, 3, ...}, is a finite spectrum which satisfies the property that its BP-homology, BP_(*)(V(n)):=[𝕊⁰, BP ∧ V(n)], is isomorphic to BP_(*)/(p, ..., v_(n)).
# 1	The	the	DET	DT	Definite=Def|PronType=Art	6	det	_	_
# 2	nth	nth	ADJ	JJ	Number=Sing	6	amod	_	_
# 3	Toda	Toda	PROPN	NNP	Number=Sing	5	compound	_	SpaceAfter=No
# 4	-	-	PUNCT	HYPH	_	5	punct	_	SpaceAfter=No
# 5	Smith	Smith	PROPN	NNP	Number=Sing	6	compound	_	_
# 6	complex	complex	NOUN	NN	Number=Sing	31	nsubj	_	SpaceAfter=No
# 7	,	,	PUNCT	,	_	6	punct	_	_
# 8	V	v	NOUN	NN	Number=Sing	6	appos	_	SpaceAfter=No
# 9	(	(	PUNCT	-LRB-	_	10	punct	_	SpaceAfter=No
# 10	n	n	NOUN	NN	Number=Sing	8	appos	_	SpaceAfter=No
# 11	)	)	PUNCT	-RRB-	_	10	punct	_	_
# 12	where	where	ADV	WRB	PronType=Rel	14	advmod	_	_
# 13	n	n	PRON	NN	Number=Sing	14	nsubj	_	SpacesAfter=
# 14	∈	∈	SYM	SYM	Mood=Ind|Tense=Past|VerbForm=Fin	6	acl:relcl	_	SpacesAfter=
# 15	{	{	PUNCT	-LRB-	_	16	punct	_	SpacesAfter=
# 16	−	−	SYM	SYM	_	14	obj	_	SpacesAfter=
# 17	1	1	NUM	CD	NumType=Card	16	nummod	_	SpaceAfter=No
# 18	,	,	PUNCT	,	_	19	punct	_	SpacesAfter=
# 19	0	0	NUM	CD	NumType=Card	16	conj	_	SpaceAfter=No
# 20	,	,	PUNCT	,	_	21	punct	_	SpacesAfter=
# 21	1	1	NUM	CD	NumType=Card	16	conj	_	SpaceAfter=No
# 22	,	,	PUNCT	,	_	23	punct	_	SpacesAfter=
# 23	2	2	NUM	CD	NumType=Card	16	conj	_	SpaceAfter=No
# 24	,	,	PUNCT	,	_	25	punct	_	SpacesAfter=
# 25	3	3	NUM	CD	NumType=Card	16	conj	_	SpaceAfter=No
# 26	,	,	PUNCT	,	_	31	punct	_	SpacesAfter=
# 27	...},	...},	PUNCT	,	_	31	punct	_	_
# 28	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	31	cop	_	_
# 29	a	a	DET	DT	Definite=Ind|PronType=Art	31	det	_	SpacesAfter=\n
# 30	finite	finite	ADJ	JJ	Degree=Pos	31	amod	_	_
# 31	spectrum	spectrum	NOUN	NN	Number=Sing	0	root	_	_
# 32	which	which	PRON	WDT	PronType=Rel	33	nsubj	_	_
# 33	satisfies	satisfy	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	31	acl:relcl	_	_
# 34	the	the	DET	DT	Definite=Def|PronType=Art	35	det	_	_
# 35	property	property	NOUN	NN	Number=Sing	33	obj	_	_
# 36	that	that	SCONJ	IN	_	63	mark	_	_
# 37	its	its	PRON	PRP$	Gender=Neut|Number=Sing|Person=3|Poss=Yes|PronType=Prs	40	nmod:poss	_	_
# 38	BP	bp	NOUN	NN	Number=Sing	40	compound	_	SpaceAfter=No
# 39	-	-	PUNCT	HYPH	_	40	punct	_	SpaceAfter=No
# 40	homology	homology	NOUN	NN	Number=Sing	63	nsubj	_	SpaceAfter=No
# 41	,	,	PUNCT	,	_	40	punct	_	SpacesAfter=\n
# 42	BP	bp	NOUN	NN	Number=Sing	40	appos	_	SpaceAfter=No
# 43	_	_	SYM	NFP	_	40	punct	_	SpaceAfter=No
# 44	(	(	PUNCT	-LRB-	_	47	punct	_	SpaceAfter=No
# 45	*)	*)	SYM	NFP	_	40	punct	_	SpaceAfter=No
# 46	(	(	PUNCT	-LRB-	_	47	punct	_	SpaceAfter=No
# 47	V	v	NOUN	NN	Number=Sing	40	appos	_	SpaceAfter=No
# 48	(	(	PUNCT	-LRB-	_	49	punct	_	SpaceAfter=No
# 49	n	n	NOUN	NN	Number=Sing	47	appos	_	SpaceAfter=No
# 50	))	))	PUNCT	-RRB-	_	49	punct	_	SpaceAfter=No
# 51	:=[	:=[	SYM	NFP	_	40	punct	_	SpaceAfter=No
# 52	𝕊⁰	𝕊⁰	NOUN	NN	Number=Sing	40	appos	_	SpaceAfter=No
# 53	,	,	PUNCT	,	_	47	punct	_	SpacesAfter=
# 54	BP	bp	NOUN	NN	Number=Sing	52	appos	_	SpacesAfter=
# 55	∧	∧	SYM	CC	_	56	case	_	SpacesAfter=
# 56	V	v	NOUN	NN	Number=Sing	52	nmod	_	SpaceAfter=No
# 57	(	(	PUNCT	-LRB-	_	58	punct	_	SpaceAfter=No
# 58	n	n	NOUN	NN	Number=Sing	52	appos	_	SpaceAfter=No
# 59	)	)	PUNCT	-RRB-	_	58	punct	_	SpaceAfter=No
# 60	]	]	PUNCT	-RRB-	_	52	punct	_	SpaceAfter=No
# 61	,	,	PUNCT	,	_	63	punct	_	_
# 62	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	63	cop	_	_
# 63	isomorphic	isomorphic	ADJ	JJ	Degree=Pos	35	acl	_	_
# 64	to	to	ADP	IN	_	65	case	_	_
# 65	BP	bp	NOUN	NN	Number=Sing	63	obl	_	SpaceAfter=No
# 66	_	_	SYM	NFP	_	65	punct	_	SpaceAfter=No
# 67	(	(	PUNCT	-LRB-	_	71	punct	_	SpaceAfter=No
# 68	*)	*)	SYM	NFP	_	65	punct	_	SpaceAfter=No
# 69	/	/	PUNCT	,	_	71	punct	_	SpaceAfter=No
# 70	(	(	PUNCT	-LRB-	_	71	punct	_	SpaceAfter=No
# 71	p	p	NOUN	NN	Number=Sing	65	appos	_	SpaceAfter=No
# 72	,	,	PUNCT	,	_	71	punct	_	SpacesAfter=
# 73	...	...	PUNCT	,	_	71	punct	_	SpaceAfter=No
# 74	,	,	PUNCT	,	_	71	punct	_	SpacesAfter=
# 75	v_(	v_(	X	AFX	_	76	compound	_	SpaceAfter=No
# 76	n	n	NOUN	NN	Number=Sing	71	nummod	_	SpaceAfter=No
# 77	)	)	PUNCT	-RRB-	_	71	punct	_	SpaceAfter=No
# 78	)	)	PUNCT	-RRB-	_	71	punct	_	SpaceAfter=No
# 79	.	.	PUNCT	.	_	31	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 14
# # text = That is, Toda-Smith complexes are completely characterized by their BP-local properties, and are defined as any object V(n) satisfying one of the following equations:
# 1	That	that	PRON	DT	Number=Sing|PronType=Dem	2	nsubj	_	_
# 2	is	be	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	10	advcl	_	SpaceAfter=No
# 3	,	,	PUNCT	,	_	10	punct	_	_
# 4	Toda	Toda	PROPN	NNP	Number=Sing	6	compound	_	SpaceAfter=No
# 5	-	-	PUNCT	HYPH	_	6	punct	_	SpaceAfter=No
# 6	Smith	Smith	PROPN	NNP	Number=Sing	7	compound	_	_
# 7	complexes	complex	NOUN	NNS	Number=Plur	10	nsubj:pass	_	_
# 8	are	be	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	10	aux:pass	_	_
# 9	completely	completely	ADV	RB	_	10	advmod	_	_
# 10	characterized	characterize	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	0	root	_	_
# 11	by	by	ADP	IN	_	16	case	_	_
# 12	their	they	PRON	PRP$	Number=Plur|Person=3|Poss=Yes|PronType=Prs	16	nmod:poss	_	SpacesAfter=\n
# 13	BP	bp	NOUN	NN	Number=Sing	15	compound	_	SpaceAfter=No
# 14	-	-	PUNCT	HYPH	_	15	punct	_	SpaceAfter=No
# 15	local	local	ADJ	JJ	Degree=Pos	16	amod	_	_
# 16	properties	property	NOUN	NNS	Number=Plur	10	obl	_	SpaceAfter=No
# 17	,	,	PUNCT	,	_	20	punct	_	_
# 18	and	and	CCONJ	CC	_	20	cc	_	_
# 19	are	be	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	20	aux:pass	_	_
# 20	defined	define	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	10	conj	_	_
# 21	as	as	ADP	IN	_	23	case	_	_
# 22	any	any	DET	DT	_	23	det	_	_
# 23	object	object	NOUN	NN	Number=Sing	20	obl	_	_
# 24	V	v	NOUN	NN	Number=Sing	23	appos	_	SpaceAfter=No
# 25	(	(	PUNCT	-LRB-	_	26	punct	_	SpaceAfter=No
# 26	n	n	NOUN	NN	Number=Sing	24	appos	_	SpaceAfter=No
# 27	)	)	PUNCT	-RRB-	_	26	punct	_	_
# 28	satisfying	satisfy	VERB	VBG	VerbForm=Ger	23	acl	_	_
# 29	one	one	NUM	CD	NumType=Card	28	obj	_	SpacesAfter=\n
# 30	of	of	ADP	IN	_	33	case	_	_
# 31	the	the	DET	DT	Definite=Def|PronType=Art	33	det	_	_
# 32	following	follow	VERB	VBG	VerbForm=Ger	33	amod	_	_
# 33	equations	equation	NOUN	NNS	Number=Plur	29	nmod	_	SpaceAfter=No
# 34	:	:	PUNCT	:	_	10	punct	_	SpacesAfter=\n\n\s\s\s\s
#
# # newpar
# # sent_id = 15
# # text = BP_(*)(V( − 1)) ≃ BP_(*) BP_(*)(V(0)) ≃ BP_(*)/p BP_(*)(V(1)) ≃ BP_(*)/(p, v₁) etc.
# 1	BP	bp	NOUN	NN	Number=Sing	0	root	_	SpaceAfter=No
# 2	_	_	SYM	NFP	_	1	punct	_	SpaceAfter=No
# 3	(	(	PUNCT	-LRB-	_	6	punct	_	SpaceAfter=No
# 4	*)	*)	SYM	NFP	_	1	punct	_	SpaceAfter=No
# 5	(	(	PUNCT	-LRB-	_	6	punct	_	SpaceAfter=No
# 6	V	v	NOUN	NN	Number=Sing	1	appos	_	SpaceAfter=No
# 7	(	(	PUNCT	-LRB-	_	6	punct	_	SpacesAfter=
# 8	−	−	SYM	SYM	_	6	appos	_	SpacesAfter=
# 9	1	1	NUM	CD	NumType=Card	8	nummod	_	SpaceAfter=No
# 10	)	)	PUNCT	-RRB-	_	6	punct	_	SpaceAfter=No
# 11	)	)	PUNCT	-RRB-	_	6	punct	_	SpacesAfter=
# 12	≃	≃	PUNCT	NFP	_	1	punct	_	SpacesAfter=
# 13	BP	bp	NOUN	NN	Number=Sing	1	list	_	SpaceAfter=No
# 14	_	_	SYM	NFP	_	13	punct	_	SpaceAfter=No
# 15	(	(	PUNCT	-LRB-	_	17	punct	_	SpaceAfter=No
# 16	*)	*)	SYM	NFP	_	17	punct	_	SpacesAfter=\n\s\s\s\s
# 17	BP_	bp_	NOUN	NN	Number=Sing	13	appos	_	SpaceAfter=No
# 18	(	(	PUNCT	-LRB-	_	17	punct	_	SpaceAfter=No
# 19	*)	*)	SYM	NFP	_	17	punct	_	SpaceAfter=No
# 20	(	(	PUNCT	-LRB-	_	21	punct	_	SpaceAfter=No
# 21	V	v	NOUN	NN	Number=Sing	17	appos	_	SpaceAfter=No
# 22	(	(	PUNCT	-LRB-	_	23	punct	_	SpaceAfter=No
# 23	0	0	NUM	CD	NumType=Card	21	nummod	_	SpaceAfter=No
# 24	)	)	PUNCT	-RRB-	_	21	punct	_	SpaceAfter=No
# 25	)	)	PUNCT	-RRB-	_	17	punct	_	SpacesAfter=
# 26	≃	≃	PUNCT	NFP	_	27	punct	_	SpacesAfter=
# 27	BP	bp	NOUN	NN	Number=Sing	1	list	_	SpaceAfter=No
# 28	_	_	SYM	NFP	_	27	punct	_	SpaceAfter=No
# 29	(	(	PUNCT	-LRB-	_	32	punct	_	SpaceAfter=No
# 30	*)	*)	SYM	NFP	_	32	punct	_	SpaceAfter=No
# 31	/	/	PUNCT	,	_	32	punct	_	SpaceAfter=No
# 32	p	p	NOUN	NN	Number=Sing	27	appos	_	SpacesAfter=\n\s\s\s\s
# 33	BP	bp	NOUN	NN	Number=Sing	1	list	_	SpaceAfter=No
# 34	_	_	SYM	NFP	_	27	punct	_	SpaceAfter=No
# 35	(	(	PUNCT	-LRB-	_	38	punct	_	SpaceAfter=No
# 36	*)	*)	SYM	NFP	_	38	punct	_	SpaceAfter=No
# 37	(	(	PUNCT	-LRB-	_	38	punct	_	SpaceAfter=No
# 38	V	v	NOUN	NN	Number=Sing	33	appos	_	SpaceAfter=No
# 39	(	(	PUNCT	-LRB-	_	38	punct	_	SpaceAfter=No
# 40	1	1	NUM	CD	NumType=Card	38	nummod	_	SpaceAfter=No
# 41	)	)	PUNCT	-RRB-	_	38	punct	_	SpaceAfter=No
# 42	)	)	PUNCT	-RRB-	_	38	punct	_	SpacesAfter=
# 43	≃	≃	PUNCT	NFP	_	44	punct	_	SpacesAfter=
# 44	BP	bp	NOUN	NN	Number=Sing	1	list	_	SpaceAfter=No
# 45	_	_	SYM	NFP	_	44	punct	_	SpaceAfter=No
# 46	(	(	PUNCT	-LRB-	_	50	punct	_	SpaceAfter=No
# 47	*)	*)	SYM	NFP	_	44	punct	_	SpaceAfter=No
# 48	/	/	PUNCT	,	_	50	punct	_	SpaceAfter=No
# 49	(	(	PUNCT	-LRB-	_	50	punct	_	SpaceAfter=No
# 50	p	p	NOUN	NN	Number=Sing	44	appos	_	SpaceAfter=No
# 51	,	,	PUNCT	,	_	50	punct	_	SpacesAfter=
# 52	v₁	v₁	NOUN	NN	Number=Sing	50	appos	_	SpaceAfter=No
# 53	)	)	PUNCT	-RRB-	_	50	punct	_	SpacesAfter=\n\s\s\s\s
# 54	etc	etc	X	FW	_	1	list	_	SpaceAfter=No
# 55	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 16
# # text = Examples of Toda-Smith complexes
# 1	Examples	example	NOUN	NNS	Number=Plur	0	root	_	_
# 2	of	of	ADP	IN	_	6	case	_	_
# 3	Toda	Toda	PROPN	NNP	Number=Sing	5	compound	_	SpaceAfter=No
# 4	-	-	PUNCT	HYPH	_	5	punct	_	SpaceAfter=No
# 5	Smith	Smith	PROPN	NNP	Number=Sing	6	compound	_	_
# 6	complexes	complex	NOUN	NNS	Number=Plur	1	nmod	_	SpacesAfter=\n\n\s\s\s\s
#
# # newpar
# # sent_id = 17
# # text = the sphere spectrum, BP_(*)(S⁰) ≃ BP_(*), which is V( − 1).
# 1	the	the	DET	DT	Definite=Def|PronType=Art	3	det	_	_
# 2	sphere	sphere	NOUN	NN	Number=Sing	3	compound	_	_
# 3	spectrum	spectrum	NOUN	NN	Number=Sing	0	root	_	SpaceAfter=No
# 4	,	,	PUNCT	,	_	3	punct	_	_
# 5	BP	bp	NOUN	NN	Number=Sing	3	appos	_	SpaceAfter=No
# 6	_	_	SYM	SYM	_	5	punct	_	SpaceAfter=No
# 7	(	(	PUNCT	-LRB-	_	10	punct	_	SpaceAfter=No
# 8	*)	*)	SYM	NFP	_	10	punct	_	SpaceAfter=No
# 9	(	(	PUNCT	-LRB-	_	10	punct	_	SpaceAfter=No
# 10	S⁰	s⁰	NOUN	NN	Number=Sing	5	appos	_	SpaceAfter=No
# 11	)	)	PUNCT	-RRB-	_	10	punct	_	SpacesAfter=
# 12	≃	≃	SYM	NFP	_	3	punct	_	SpacesAfter=
# 13	BP_	bp_	NOUN	NN	Number=Sing	3	appos	_	SpaceAfter=No
# 14	(	(	PUNCT	-LRB-	_	13	punct	_	SpaceAfter=No
# 15	*	*	SYM	NFP	_	13	appos	_	SpaceAfter=No
# 16	)	)	PUNCT	-RRB-	_	13	punct	_	SpaceAfter=No
# 17	,	,	PUNCT	,	_	13	punct	_	_
# 18	which	which	PRON	WDT	PronType=Rel	20	nsubj	_	_
# 19	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	20	cop	_	_
# 20	V	v	NOUN	NN	Number=Sing	13	acl:relcl	_	SpaceAfter=No
# 21	(	(	PUNCT	-LRB-	_	22	punct	_	SpacesAfter=
# 22	−	−	SYM	SYM	Number=Sing	20	appos	_	SpacesAfter=
# 23	1	1	NUM	CD	NumType=Card	22	nummod	_	SpaceAfter=No
# 24	)	)	PUNCT	-RRB-	_	22	punct	_	SpaceAfter=No
# 25	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n\s\s\s\s
#
# # sent_id = 18
# # text = the mod p Moore spectrum, BP_(*)(S/p) ≃ BP_(*)/p, which is V(0)
# 1	the	the	DET	DT	Definite=Def|PronType=Art	5	det	_	_
# 2	mod	mod	NOUN	NN	Number=Sing	5	compound	_	_
# 3	p	p	NOUN	NN	Number=Sing	5	compound	_	_
# 4	Moore	Moore	PROPN	NNP	Number=Sing	5	compound	_	_
# 5	spectrum	spectrum	NOUN	NN	Number=Sing	0	root	_	SpaceAfter=No
# 6	,	,	PUNCT	,	_	5	punct	_	_
# 7	BP	bp	NOUN	NN	Number=Sing	5	appos	_	SpaceAfter=No
# 8	_	_	SYM	NFP	_	7	punct	_	SpaceAfter=No
# 9	(	(	PUNCT	-LRB-	_	13	punct	_	SpaceAfter=No
# 10	*	*	SYM	NFP	_	7	punct	_	SpaceAfter=No
# 11	)	)	PUNCT	-RRB-	_	13	punct	_	SpaceAfter=No
# 12	(	(	PUNCT	-LRB-	_	13	punct	_	SpaceAfter=No
# 13	S/p	s/p	NOUN	NN	Number=Sing	7	appos	_	SpaceAfter=No
# 14	)	)	PUNCT	-RRB-	_	13	punct	_	SpacesAfter=
# 15	≃	≃	SYM	NFP	_	5	punct	_	SpacesAfter=
# 16	BP	bp	NOUN	NN	Number=Sing	5	conj	_	SpaceAfter=No
# 17	_	_	SYM	NFP	_	16	punct	_	SpaceAfter=No
# 18	(*)	(*)	SYM	NFP	_	16	punct	_	SpaceAfter=No
# 19	/p	/p	SYM	NN	_	16	appos	_	SpaceAfter=No
# 20	,	,	PUNCT	,	_	16	punct	_	_
# 21	which	which	PRON	WDT	PronType=Rel	23	nsubj	_	_
# 22	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	23	cop	_	_
# 23	V	v	NOUN	NN	Number=Sing	16	acl:relcl	_	SpaceAfter=No
# 24	(	(	PUNCT	-LRB-	_	25	punct	_	SpaceAfter=No
# 25	0	0	NUM	CD	NumType=Card	23	appos	_	SpaceAfter=No
# 26	)	)	PUNCT	-RRB-	_	25	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 19
# # text = Relevance to stable homotopy theory
# 1	Relevance	relevance	NOUN	NN	Number=Sing	0	root	_	_
# 2	to	to	ADP	IN	_	5	case	_	_
# 3	stable	stable	ADJ	JJ	Degree=Pos	5	amod	_	_
# 4	homotopy	homotopy	NOUN	NN	Number=Sing	5	compound	_	_
# 5	theory	theory	NOUN	NN	Number=Sing	1	nmod	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 20
# # text = It may help the reader to recall that that BP_(*) = ℤ_(p)[v₁, v₂, ...], |v_(i)| = 2(p^(i) − 1).
# 1	It	it	PRON	PRP	Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs	3	expl	_	_
# 2	may	may	AUX	MD	VerbForm=Fin	3	aux	_	_
# 3	help	help	VERB	VB	VerbForm=Inf	0	root	_	_
# 4	the	the	DET	DT	Definite=Def|PronType=Art	5	det	_	_
# 5	reader	reader	NOUN	NN	Number=Sing	3	obj	_	_
# 6	to	to	PART	TO	_	7	mark	_	_
# 7	recall	recall	VERB	VB	VerbForm=Inf	3	xcomp	_	_
# 8	that	that	SCONJ	IN	_	14	mark	_	_
# 9	that	that	SCONJ	IN	_	14	mark	_	_
# 10	BP_	bp_	NOUN	NN	Number=Sing	14	nsubj	_	SpaceAfter=No
# 11	(	(	PUNCT	-LRB-	_	10	punct	_	SpaceAfter=No
# 12	*	*	SYM	NFP	_	10	appos	_	SpaceAfter=No
# 13	)	)	PUNCT	-RRB-	_	10	punct	_	SpacesAfter=
# 14	=	=	SYM	SYM	_	7	ccomp	_	SpacesAfter=
# 15	ℤ_	ℤ_	SYM	NN	Number=Sing	14	obj	_	SpaceAfter=No
# 16	(	(	PUNCT	-LRB-	_	17	punct	_	SpaceAfter=No
# 17	p	p	NOUN	NN	Number=Sing	15	appos	_	SpaceAfter=No
# 18	)	)	PUNCT	-RRB-	_	17	punct	_	SpaceAfter=No
# 19	[	[	PUNCT	-LRB-	_	20	punct	_	SpaceAfter=No
# 20	v₁	v₁	NOUN	NN	Number=Sing	15	appos	_	SpaceAfter=No
# 21	,	,	PUNCT	,	_	22	punct	_	SpacesAfter=
# 22	v₂	v₂	NOUN	NN	Number=Sing	20	conj	_	SpaceAfter=No
# 23	,	,	PUNCT	,	_	20	punct	_	SpacesAfter=
# 24	...	...	PUNCT	,	_	20	punct	_	SpaceAfter=No
# 25	]	]	PUNCT	-RRB-	_	20	punct	_	SpaceAfter=No
# 26	,	,	PUNCT	,	_	15	punct	_	SpacesAfter=\n
# 27	|v_(	|v_(	SYM	NFP	_	28	compound	_	SpaceAfter=No
# 28	i	i	NUM	CD	NumType=Card	31	nummod	_	SpaceAfter=No
# 29	)	)	PUNCT	-RRB-	_	28	punct	_	SpaceAfter=No
# 30	|	|	PUNCT	''	_	31	punct	_	SpacesAfter=
# 31	=	=	SYM	SYM	_	15	conj	_	SpacesAfter=
# 32	2	2	NUM	CD	NumType=Card	31	nummod	_	SpaceAfter=No
# 33	(	(	PUNCT	-LRB-	_	34	punct	_	SpaceAfter=No
# 34	p^	p^	NOUN	NN	Number=Sing	31	appos	_	SpaceAfter=No
# 35	(	(	PUNCT	-LRB-	_	36	punct	_	SpaceAfter=No
# 36	i	i	NUM	CD	NumType=Card	34	nummod	_	SpaceAfter=No
# 37	)	)	PUNCT	-RRB-	_	34	punct	_	SpacesAfter=
# 38	−	−	SYM	SYM	_	31	parataxis	_	SpacesAfter=
# 39	1	1	NUM	CD	NumType=Card	38	nummod	_	SpaceAfter=No
# 40	)	)	PUNCT	-RRB-	_	34	punct	_	SpaceAfter=No
# 41	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 21
# # text = The periodic maps, α_(t), β_(t), and γ_(t), come from degree maps between the Toda-Smith complexes, V(0)_(k), V(1)_(k), and V(2)_(k) respectively.
# 1	The	the	DET	DT	Definite=Def|PronType=Art	3	det	_	_
# 2	periodic	periodic	ADJ	JJ	Degree=Pos	3	amod	_	_
# 3	maps	map	NOUN	NNS	Number=Plur	21	nsubj	_	SpaceAfter=No
# 4	,	,	PUNCT	,	_	3	punct	_	_
# 5	α_	α_	SYM	NN	_	3	appos	_	SpaceAfter=No
# 6	(	(	PUNCT	-LRB-	_	7	punct	_	SpaceAfter=No
# 7	t	t	NOUN	NN	Number=Sing	3	appos	_	SpaceAfter=No
# 8	)	)	PUNCT	-RRB-	_	7	punct	_	SpaceAfter=No
# 9	,	,	PUNCT	,	_	10	punct	_	SpacesAfter=
# 10	β_	β_	NOUN	NN	Number=Sing	5	conj	_	SpaceAfter=No
# 11	(	(	PUNCT	-LRB-	_	12	punct	_	SpaceAfter=No
# 12	t	t	NOUN	NN	Number=Sing	10	appos	_	SpaceAfter=No
# 13	)	)	PUNCT	-RRB-	_	12	punct	_	SpaceAfter=No
# 14	,	,	PUNCT	,	_	16	punct	_	_
# 15	and	and	CCONJ	CC	_	16	cc	_	_
# 16	γ_	γ_	NOUN	NN	Number=Sing	3	conj	_	SpaceAfter=No
# 17	(	(	PUNCT	-LRB-	_	18	punct	_	SpaceAfter=No
# 18	t	t	NOUN	NN	Number=Sing	16	appos	_	SpaceAfter=No
# 19	)	)	PUNCT	-RRB-	_	18	punct	_	SpaceAfter=No
# 20	,	,	PUNCT	,	_	21	punct	_	_
# 21	come	come	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	0	root	_	_
# 22	from	from	ADP	IN	_	24	case	_	_
# 23	degree	degree	NOUN	NN	Number=Sing	24	compound	_	_
# 24	maps	map	NOUN	NNS	Number=Plur	21	obl	_	SpacesAfter=\n
# 25	between	between	ADP	IN	_	30	case	_	_
# 26	the	the	DET	DT	Definite=Def|PronType=Art	30	det	_	_
# 27	Toda	Toda	PROPN	NNP	Number=Sing	29	compound	_	SpaceAfter=No
# 28	-	-	PUNCT	HYPH	_	29	punct	_	SpaceAfter=No
# 29	Smith	Smith	PROPN	NNP	Number=Sing	30	compound	_	_
# 30	complexes	complex	NOUN	NNS	Number=Plur	24	nmod	_	SpaceAfter=No
# 31	,	,	PUNCT	,	_	30	punct	_	_
# 32	V	v	NOUN	NN	Number=Sing	30	appos	_	SpaceAfter=No
# 33	(	(	PUNCT	-LRB-	_	34	punct	_	SpaceAfter=No
# 34	0	0	NUM	CD	NumType=Card	32	nummod	_	SpaceAfter=No
# 35	)	)	PUNCT	-RRB-	_	38	punct	_	SpaceAfter=No
# 36	_	_	SYM	NFP	_	30	punct	_	SpaceAfter=No
# 37	(	(	PUNCT	-LRB-	_	38	punct	_	SpaceAfter=No
# 38	k	k	NUM	CD	NumType=Card	32	appos	_	SpaceAfter=No
# 39	)	)	PUNCT	-RRB-	_	38	punct	_	SpaceAfter=No
# 40	,	,	PUNCT	,	_	41	punct	_	SpacesAfter=
# 41	V	v	NOUN	NN	Number=Sing	30	conj	_	SpaceAfter=No
# 42	(	(	PUNCT	-LRB-	_	47	punct	_	SpaceAfter=No
# 43	1	1	NUM	CD	NumType=Card	41	nummod	_	SpaceAfter=No
# 44	)	)	PUNCT	-RRB-	_	47	punct	_	SpaceAfter=No
# 45	_	_	SYM	NFP	_	41	punct	_	SpaceAfter=No
# 46	(	(	PUNCT	-LRB-	_	47	punct	_	SpaceAfter=No
# 47	k	k	NOUN	NN	Number=Sing	41	appos	_	SpaceAfter=No
# 48	)	)	PUNCT	-RRB-	_	47	punct	_	SpaceAfter=No
# 49	,	,	PUNCT	,	_	51	punct	_	_
# 50	and	and	CCONJ	CC	_	51	cc	_	_
# 51	V	v	NOUN	NN	Number=Sing	30	conj	_	SpaceAfter=No
# 52	(	(	PUNCT	-LRB-	_	57	punct	_	SpaceAfter=No
# 53	2	2	NUM	CD	NumType=Card	51	nummod	_	SpaceAfter=No
# 54	)	)	PUNCT	-RRB-	_	57	punct	_	SpaceAfter=No
# 55	_	_	SYM	NFP	_	51	punct	_	SpaceAfter=No
# 56	(	(	PUNCT	-LRB-	_	57	punct	_	SpaceAfter=No
# 57	k	k	NOUN	NN	NumType=Card	51	appos	_	SpaceAfter=No
# 58	)	)	PUNCT	-RRB-	_	57	punct	_	SpacesAfter=\n
# 59	respectively	respectively	ADV	RB	_	51	advmod	_	SpaceAfter=No
# 60	.	.	PUNCT	.	_	21	punct	_	SpacesAfter=\n\n
#
# # newpar
# # sent_id = 22
# # text = (… add in their relation to the v₂ periodic elements, and the reasoning behind the shift 2(p^(i) − 1))
# 1	(…	(…	PUNCT	-LRB-	_	2	punct	_	_
# 2	add	add	VERB	VB	Mood=Imp|VerbForm=Fin	0	root	_	_
# 3	in	in	ADP	IN	_	5	case	_	_
# 4	their	they	PRON	PRP$	Number=Plur|Person=3|Poss=Yes|PronType=Prs	5	nmod:poss	_	_
# 5	relation	relation	NOUN	NN	Number=Sing	2	obl	_	_
# 6	to	to	ADP	IN	_	10	case	_	_
# 7	the	the	DET	DT	Definite=Def|PronType=Art	10	det	_	_
# 8	v₂	v₂	NOUN	NN	Number=Sing	10	compound	_	_
# 9	periodic	periodic	ADJ	JJ	Degree=Pos	10	amod	_	_
# 10	elements	element	NOUN	NNS	Number=Plur	5	nmod	_	SpaceAfter=No
# 11	,	,	PUNCT	,	_	14	punct	_	_
# 12	and	and	CCONJ	CC	_	14	cc	_	_
# 13	the	the	DET	DT	Definite=Def|PronType=Art	14	det	_	_
# 14	reasoning	reasoning	NOUN	NN	Number=Sing	5	conj	_	SpacesAfter=\n
# 15	behind	behind	ADP	IN	_	17	case	_	_
# 16	the	the	DET	DT	Definite=Def|PronType=Art	17	det	_	_
# 17	shift	shift	NOUN	NN	Number=Sing	14	nmod	_	_
# 18	2	2	NUM	CD	NumType=Card	17	nummod	_	SpaceAfter=No
# 19	(	(	PUNCT	-LRB-	_	20	punct	_	SpaceAfter=No
# 20	p^	p^	NOUN	NN	Number=Sing	17	appos	_	SpaceAfter=No
# 21	(	(	PUNCT	-LRB-	_	22	punct	_	SpaceAfter=No
# 22	i	i	NUM	CD	NumType=Card	20	nummod	_	SpaceAfter=No
# 23	)	)	PUNCT	-RRB-	_	22	punct	_	SpacesAfter=
# 24	−	−	SYM	SYM	_	17	appos	_	SpacesAfter=
# 25	1	1	NUM	CD	NumType=Card	24	nummod	_	SpaceAfter=No
# 26	)	)	PUNCT	-RRB-	_	20	punct	_	SpaceAfter=No
# 27	)	)	PUNCT	-RRB-	_	2	punct	_	SpacesAfter=\n

# %%
ct = 0
for i in read_file:
    input_data = i['content']

    files = {
        'data': (None, input_data),
        'model': (None, 'english'),
        'tokenizer': (None, ''),
        'tagger': (None, ''),
        'parser': (None, ''),
    }

    response = requests.post('http://lindat.mff.cuni.cz/services/udpipe/api/process', files=files)
    byte_str = response.content
    dict_str = byte_str.decode("UTF-8")
    mydata = ast.literal_eval(dict_str)
    out = mydata['result']
    i['UD Results'] = out
    ct += 1
    if ct % 100 == 0:
        print(ct/len(read_file))
# Out:
# 0.008581481163648846
# 0.017162962327297693
# 0.025744443490946536
# 0.034325924654595386
# 0.04290740581824423
# 0.05148888698189307
# 0.06007036814554192
# 0.06865184930919077
# 0.07723333047283962
# 0.08581481163648846
# 0.09439629280013731
# 0.10297777396378614
# 0.11155925512743499
# 0.12014073629108384
# 0.1287222174547327
# 0.13730369861838154
# 0.1458851797820304
# 0.15446666094567923
# 0.16304814210932808
# 0.17162962327297693
# 0.18021110443662577
# 0.18879258560027462
# 0.19737406676392347
# 0.20595554792757229
# 0.21453702909122113
# 0.22311851025486998
# 0.23169999141851882
# 0.24028147258216767
# 0.24886295374581652
# 0.2574444349094654
# 0.2660259160731142
# 0.2746073972367631
# 0.2831888784004119
# 0.2917703595640608
# 0.3003518407277096
# 0.30893332189135847
# 0.3175148030550073
# 0.32609628421865616
# 0.334677765382305
# 0.34325924654595386
# 0.3518407277096027
# 0.36042220887325155
# 0.36900369003690037
# 0.37758517120054924
# 0.38616665236419806
# 0.39474813352784693
# 0.40332961469149575
# 0.41191109585514457
# 0.42049257701879345
# 0.42907405818244226
# 0.43765553934609114
# 0.44623702050973996
# 0.45481850167338883
# 0.46339998283703765
# 0.4719814640006865
# 0.48056294516433534
# 0.4891444263279842
# 0.49772590749163304
# 0.5063073886552819
# 0.5148888698189308
# 0.5234703509825795
# 0.5320518321462284
# 0.5406333133098773
# 0.5492147944735262
# 0.5577962756371749
# 0.5663777568008238
# 0.5749592379644727
# 0.5835407191281216
# 0.5921222002917703
# 0.6007036814554192
# 0.6092851626190681
# 0.6178666437827169
# 0.6264481249463657
# 0.6350296061100146
# 0.6436110872736635
# 0.6521925684373123
# 0.6607740496009611
# 0.66935553076461
# 0.6779370119282588
# 0.6865184930919077
# 0.6950999742555565
# 0.7036814554192053
# 0.7122629365828542
# 0.7208444177465031
# 0.7294258989101519
# 0.7380073800738007
# 0.7465888612374496
# 0.7551703424010985
# 0.7637518235647472
# 0.7723333047283961
# 0.780914785892045
# 0.7894962670556939
# 0.7980777482193426
# 0.8066592293829915
# 0.8152407105466404
# 0.8238221917102891
# 0.832403672873938
# 0.8409851540375869
# 0.8495666352012358
# 0.8581481163648845
# 0.8667295975285334
# 0.8753110786921823
# 0.8838925598558312
# 0.8924740410194799
# 0.9010555221831288
# 0.9096370033467777
# 0.9182184845104265
# 0.9267999656740753
# 0.9353814468377242
# 0.943962928001373
# 0.9525444091650219
# 0.9611258903286707
# 0.9697073714923196
# 0.9782888526559684
# 0.9868703338196173
# 0.9954518149832661

# %%
read_file[1]['UD Results']
# Out:
# "# generator = UDPipe 2, https://lindat.mff.cuni.cz/services/udpipe\n# udpipe_model = english-ewt-ud-2.6-200830\n# udpipe_model_licence = CC BY-NC-SA\n# newdoc\n# newpar\n# sent_id = 1\n# text = ##Informal definition##\n1\t##Informal\t##informal\tADJ\tJJ\tDegree=Pos\t2\tamod\t_\t_\n2\tdefinition\tdefinition\tNOUN\tNN\tNumber=Sing\t0\troot\t_\tSpaceAfter=No\n3\t##\t##\tSYM\tNFP\t_\t2\tpunct\t_\tSpacesAfter=\\n\\n\n\n# newpar\n# sent_id = 2\n# text = Toda-Smith complexes are finite spectra characterized by having a particularly simple homology, and are used in stable homotopy theory.\n1\tToda\tToda\tPROPN\tNNP\tNumber=Sing\t3\tcompound\t_\tSpaceAfter=No\n2\t-Smith\t-smith\tPROPN\tNNP\tNumber=Sing\t1\tflat\t_\t_\n3\tcomplexes\tcomplex\tNOUN\tNNS\tNumber=Plur\t6\tnsubj\t_\t_\n4\tare\tbe\tAUX\tVBP\tMood=Ind|Tense=Pres|VerbForm=Fin\t6\tcop\t_\t_\n5\tfinite\tfinite\tADJ\tJJ\tDegree=Pos\t6\tamod\t_\t_\n6\tspectra\tspectra\tNOUN\tNN\tNumber=Sing\t0\troot\t_\t_\n7\tcharacterized\tcharacterize\tVERB\tVBN\tTense=Past|VerbForm=Part\t6\tacl\t_\t_\n8\tby\tby\tSCONJ\tIN\t_\t9\tmark\t_\t_\n9\thaving\thave\tVERB\tVBG\tVerbForm=Ger\t7\tadvcl\t_\t_\n10\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t13\tdet\t_\tSpacesAfter=\\n\n11\tparticularly\tparticularly\tADV\tRB\t_\t12\tadvmod\t_\t_\n12\tsimple\tsimple\tADJ\tJJ\tDegree=Pos\t13\tamod\t_\t_\n13\thomology\thomology\tNOUN\tNN\tNumber=Sing\t9\tobj\t_\tSpaceAfter=No\n14\t,\t,\tPUNCT\t,\t_\t17\tpunct\t_\t_\n15\tand\tand\tCCONJ\tCC\t_\t17\tcc\t_\t_\n16\tare\tbe\tAUX\tVBP\tMood=Ind|Tense=Pres|VerbForm=Fin\t17\taux:pass\t_\t_\n17\tused\tuse\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t6\tconj\t_\t_\n18\tin\tin\tADP\tIN\t_\t21\tcase\t_\t_\n19\tstable\tstable\tADJ\tJJ\tDegree=Pos\t21\tamod\t_\t_\n20\thomotopy\thomotopy\tNOUN\tNN\tNumber=Sing\t21\tcompound\t_\t_\n21\ttheory\ttheory\tNOUN\tNN\tNumber=Sing\t17\tobl\t_\tSpaceAfter=No\n22\t.\t.\tPUNCT\t.\t_\t6\tpunct\t_\tSpacesAfter=\\n\\n\n\n# newpar\n# sent_id = 3\n# text = Toda-Smith complexes provided examples of periodic maps.\n1\tToda\tToda\tPROPN\tNNP\tNumber=Sing\t4\tcompound\t_\tSpaceAfter=No\n2\t-\t-\tPUNCT\tHYPH\t_\t1\tpunct\t_\tSpaceAfter=No\n3\tSmith\tSmith\tPROPN\tNNP\tNumber=Sing\t1\tflat\t_\t_\n4\tcomplexes\tcomplex\tNOUN\tNNS\tNumber=Plur\t5\tnsubj\t_\t_\n5\tprovided\tprovide\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot\t_\t_\n6\texamples\texample\tNOUN\tNNS\tNumber=Plur\t5\tobj\t_\t_\n7\tof\tof\tADP\tIN\t_\t9\tcase\t_\t_\n8\tperiodic\tperiodic\tADJ\tJJ\tDegree=Pos\t9\tamod\t_\t_\n9\tmaps\tmap\tNOUN\tNNS\tNumber=Plur\t6\tnmod\t_\tSpaceAfter=No\n10\t.\t.\tPUNCT\t.\t_\t5\tpunct\t_\t_\n\n# sent_id = 4\n# text = Thus, they led to the construction of the nilpotent and periodicity theorems, which provided the first organization of the stable homotopy groups of spheres (localized at a prime) into families of maps via chromatic homotopy theory.\n1\tThus\tthus\tADV\tRB\t_\t4\tadvmod\t_\tSpaceAfter=No\n2\t,\t,\tPUNCT\t,\t_\t4\tpunct\t_\t_\n3\tthey\tthey\tPRON\tPRP\tCase=Nom|Number=Plur|Person=3|PronType=Prs\t4\tnsubj\t_\t_\n4\tled\tlead\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot\t_\tSpacesAfter=\\n\n5\tto\tto\tADP\tIN\t_\t7\tcase\t_\t_\n6\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t7\tdet\t_\t_\n7\tconstruction\tconstruction\tNOUN\tNN\tNumber=Sing\t4\tobl\t_\t_\n8\tof\tof\tADP\tIN\t_\t13\tcase\t_\t_\n9\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet\t_\t_\n10\tnilpotent\tnilpotent\tADJ\tJJ\tDegree=Pos\t13\tamod\t_\t_\n11\tand\tand\tCCONJ\tCC\t_\t12\tcc\t_\t_\n12\tperiodicity\tperiodicity\tNOUN\tNN\tNumber=Sing\t10\tconj\t_\t_\n13\ttheorems\ttheorem\tNOUN\tNNS\tNumber=Plur\t7\tnmod\t_\tSpaceAfter=No\n14\t,\t,\tPUNCT\t,\t_\t7\tpunct\t_\t_\n15\twhich\twhich\tPRON\tWDT\tPronType=Rel\t16\tnsubj\t_\tSpacesAfter=\\n\n16\tprovided\tprovide\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t13\tacl:relcl\t_\t_\n17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t19\tdet\t_\t_\n18\tfirst\tfirst\tADJ\tJJ\tDegree=Pos|NumType=Ord\t19\tamod\t_ ...

# %%
with open('UDPipe_nLab.json', 'w', encoding='utf-8') as f:
            json.dump(read_file, f, ensure_ascii=False, indent=4)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=59f6397f-b302-4c82-8d8a-5d16815236d3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
