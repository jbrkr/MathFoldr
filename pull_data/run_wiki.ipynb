# %%
from get_cat_members import get_cat_members
from get_subcats import get_subcats
flat_list = lambda t: [item for sublist in t for item in sublist]

# %%
subcat_master = get_subcats("Category:Mathematics")

# %%
subcat_master = [get_subcats(i) for i in subcat_master]

# %%
subcat_master = flat_list(subcat_master)

# %%
subcat_master = list(set(subcat_master))

# %%
len(subcat_master)
# Out:
# 1369

# %%
subcat_master
# Out:
# ['Category:Group theory',
#  'Category:Combinatorial game theorists',
#  'Category:12th-century English mathematicians',
#  'Category:Sparse matrices',
#  'Category:Film serials',
#  'Category:Monumental crosses',
#  'Category:Wellfoundedness',
#  'Category:20th-century American mathematicians',
#  'Category:Composition algebras',
#  'Category:Finite groups',
#  'Category:Equal temperaments',
#  'Category:Type systems',
#  'Category:Opera world premieres at the Hamburg State Opera',
#  'Category:Stable sorts',
#  'Category:Angle measuring instruments',
#  'Category:Solo piano jazz albums',
#  'Category:Network synthesis filters',
#  'Category:Helices',
#  'Category:Splines (mathematics)',
#  'Category:Gaussian function',
#  'Category:Demographers by nationality',
#  'Category:Pinball',
#  'Category:Convergence tests',
#  'Category:Automated teller machines',
#  'Category:Exchange algorithms',
#  'Category:General equilibrium theorists',
#  'Category:Theorems in plane geometry',
# ...

# %%
import csv
with open("cats.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(subcat_master)

# %%
pages = [get_cat_members(i) for i in subcat_master]

# %%
pg_flat = flat_list(pages)

# %%
pg_dedupe = list(set(pg_flat))

# %%
with open("pg_dedupe.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(pg_dedupe)

# %%
bz = '/Users/joebrucker/Downloads/enwiki-20211020-pages-articles-multistream.xml.bz2'
# Out:
# [['Category:Algebra',
#   'Category:Mathematical analysis',
#   'Category:Applied mathematics',
#   'Category:Arithmetic',
#   'Category:Combinatorics',
#   'Category:Computational mathematics',
#   'Category:Control theory',
#   'Category:Discrete mathematics',
#   'Category:Dynamical systems',
#   'Category:Elementary mathematics'],
#  ['Category:Lists of mathematics lists',
#   'Category:Cryptography lists and comparisons',
#   'Category:Glossaries of mathematics',
#   'Category:Lists of integrals',
#   'Category:Lists of mathematicians',
#   'Category:Lists of things named after mathematicians',
#   'Category:Lists of problems',
#   'Category:Lists of shapes',
#   'Category:Statistics-related lists'],
#  ['Category:Mathematicians by award',
#   'Category:Mathematicians by century',
#   'Category:Mathematicians by city',
#   'Category:Mathematicians by field',
#   'Category:Mathematicians by nationality',
#   'Category:Lists of mathematicians',
#   'Category:LGBT mathematicians',
# ...

# %%
d = bz2.decompress(c)

# %%
pages
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %%
def add_to_list(inp):
    if isinstance(inp, str):
        if len(inp) == 1:
            # done
        else if inp in subcat_master:
            # done
        else if inp[:8] != 'Category':
            # error
        else:
            subcat_master.extend(inp)
        
            
             
            
    else if isinstance(inp, list):
        
        if all(isinstance(inp, list)):
            inp = flat_list(inp)
            add_to_list(inp)
        else if any(isinstance(inp, list)):
            # flatten those lists flat_list
            temp_list_list = []
            temp_str_list = []
            for i in inp:
                if isinstance(inp, list):
                    temp_list_list.append(inp)
                if isinstance(inp, str):
                    temp_str_list.append(inp)
            temp_list_list = flat_list(temp_list_list)
            temp_str_list.extend(temp_list_list)
            inp = 
            ##
        else if all(isinstance(inp, str)):
            
        temp_list = list(set(inp))
        for i in temp_list:

# %%
list(ssub) == subf
# Out:
# False

# %%
# Out:
# list
