# %%
nlabDir_path = '/Volumes/dec15/7_9/down/stanza_nlab_out/'
stanzafilenames = []
for i in range(40):
    ct = (1+i)*25
    output_path = nlabDir_path + 'stanza_nlab_'+ str(ct) + '0.json'
    stanzafilenames.append(output_path)

# %%
import json
json_to_dict = lambda filename : json.load(open(filename,))

# %%
struct = {'id': 50,
    'text': '.',
    'lemma': '.',
    'upos': 'PUNCT',
    'xpos': '.',
    'head': 7,
    'deprel': 'punct',
    'start_char': 4382,
    'end_char': 4383,
    'ner': 'O'}

# %%
import pandas as pd 
import json
json_to_dict = lambda filename : json.load(open(filename,))

nlabDir_path = '/Volumes/dec15/7_9/down/stanza_nlab_out/'

stanzafilenames = []

for i in range(40):
    ct = (1+i)*25
    output_path = nlabDir_path + 'stanza_nlab_'+ str(ct) + '0.json'
    
    stanzafilenames.append(output_path)
    
    file = json_to_dict(stanzafilenames[0])
    print(output_path)
    for documentCt in range(len(file)):
        currDocument = file[documentCt]
        overallDocCount = (ct-25)*10+documentCt
        for sentenceCt in range(len(currDocument)):
            currSentence = currDocument[sentenceCt]
            for token in currSentence:
                token['doc_index'] = overallDocCount
                token['sent_index'] = sentenceCt                
            if overallDocCount == 0:
                stanzaDF = pd.DataFrame(currSentence)
            else: 
                currSentenceDf = pd.DataFrame(currSentence)
                stanzaDF = stanzaDF.append(currSentenceDf)
# Out:
# /Volumes/dec15/7_9/down/stanza_nlab_out/stanza_nlab_250.json
# /Volumes/dec15/7_9/down/stanza_nlab_out/stanza_nlab_500.json
# /Volumes/dec15/7_9/down/stanza_nlab_out/stanza_nlab_750.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-0a92972a2353> in <module>
#      26             else:
#      27                 currSentenceDf = pd.DataFrame(currSentence)
# ---> 28                 stanzaDF = stanzaDF.append(currSentenceDf)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7980             to_concat = [self, other]
#    7981         return (
# -> 7982             concat(
#    7983                 to_concat,
#    7984                 ignore_index=ignore_index,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     371
#     372             # consolidate
# --> 373             obj._consolidate_inplace()
#     374             ndims.add(obj.ndim)
#     375
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5539             self._mgr = self._mgr.consolidate()
#    5540
# -> 5541         self._protect_consolidate(f)
#    5542
#    5543     @final
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5527         """
#    5528         blocks_before = len(self._mgr.blocks)
# -> 5529         result = f()
#    5530         if len(self._mgr.blocks) != blocks_before:
#    5531             self._clear_item_cache()
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in f()
#    5537
#    5538         def f():
# -> 5539             self._mgr = self._mgr.consolidate()
#    5540
#    5541         self._protect_consolidate(f)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# KeyboardInterrupt:

# %%
stanzaDF['model'] = 'stanza'
stanzaDF['corpus'] = 'nLab'

# %%
file_name = 'stanza_nlab_wordlevel_so_far.csv'
stanzaDF.to_csv(file_name, sep='\t')

# %%
st = stanzaDF

# %%
cs = currSentenceDf

# %%
aa = cs.append(st)

# %%
st
# Out:
#     id     text    lemma   upos xpos        feats  head     deprel  \
# 0    1     Dror     Dror  PROPN  NNP  Number=Sing     0       root
# 1    2  Farjoun  Farjoun  PROPN  NNP  Number=Sing     1       flat
# 2    3        ,        ,  PUNCT    ,          NaN     4      punct
# 3    4    Jekel    Jekel  PROPN  NNP  Number=Sing     1       flat
# 4    5        ,        ,  PUNCT    ,          NaN     6      punct
# ..  ..      ...      ...    ...  ...          ...   ...        ...
# 1    2    field    field   NOUN   NN  Number=Sing     3   compound
# 2    3   theory   theory   NOUN   NN  Number=Sing     0       root
# 3    4       ##       ##  PUNCT    ,          NaN     3      punct
# 4    5       ##       ##  PUNCT    ,          NaN     6      punct
# 5    6  Physics  physics   NOUN   NN  Number=Sing     3  parataxis
#
#     start_char  end_char    ner  doc_index  sent_index
# 0         2055      2059  B-ORG          0          30
# 1         2060      2067  E-ORG          0          30
# 2         2067      2068      O          0          30
# 3         2069      2074  S-GPE          0          30
# 4         2074      2075      O          0          30
# ..         ...       ...    ...        ...         ...
# 1           27        32      O        701           1
# 2           33        39      O        701           1
# 3           40        42      O        701           1
# 4           42        44      O        701           1
# 5           45        52      O        701           1
#
# [609164 rows x 13 columns]
